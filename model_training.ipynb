# %%
import ultralytics
from ultralytics import YOLO
import torch
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.113  Python-3.10.4 torch-2.0.1+cu118 CUDA:0 (NVIDIA GeForce RTX 2070 SUPER, 8192MiB)
# Setup complete  (16 CPUs, 15.9 GB RAM, 565.8/931.5 GB disk)

# %%
torch.cuda.is_available()
torch.cuda.empty_cache()

# %%
torch.cuda.is_available()
# Out:
# True

# %%
model = YOLO('yolov8x-seg')

# %%
model1 = YOLO('yolov8m-seg')

# %%
train_model = model1.train(
   data="dataset.yaml",
   epochs=100,
   imgsz=512,
   batch=1,
   save=True, 
   verbose=False,
   name='HackVasculature_yolov8',
   device=0)

# %% [markdown]
# ![Results](result_images/results.png)

# %%
train_model1 = model1.train(
   data="dataset_02.yaml",
   epochs=100,
   imgsz=512,
   batch=4,
   save=True, 
   verbose=False,
   name='HackVasculature_yolov8_v2',
   device=0)

# %% [markdown]
# ![Alt text](../runs/segment/HackVasculature_yolov8_v2/results.png)

# %%
train_model2 = model.train(
   data="dataset_02.yaml",
   epochs=100,
   imgsz=512,
   batch=4,
   save=True, 
   verbose=False,
   name='HackVasculature_yolov8x_v3',
   device=0)
# Out:
# New https://pypi.org/project/ultralytics/8.0.114 available  Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.113  Python-3.10.4 torch-2.0.1+cu118 CUDA:0 (NVIDIA GeForce RTX 2070 SUPER, 8192MiB)
# ...

# %% [markdown]
# ![results.png](attachment:results.png)
